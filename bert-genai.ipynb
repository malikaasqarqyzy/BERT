# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import pandas as pd

# Read the file as plain text and manually split
with open('/kaggle/input/reviews/chatgpt_reviews_positive_negative.txt', 'r') as file:
    lines = file.readlines()

# Print first few lines to understand the structure
print(lines[:5])
# Out:
# ["I rely on ChatGPT for my everyday research and writing tasks. It's indispensable.\n", 'ChatGPT has been a game-changer for me. It saves me time and provides excellent assistance.\n', 'ChatGPT is an outstanding tool for generating text. I use it regularly for everything from emails to articles.\n', 'ChatGPT has revolutionized the way I approach my work. It’s fast, accurate, and incredibly helpful.\n', "If you're not using ChatGPT, you're missing out on a fantastic productivity tool.\n"]

# %%
import pandas as pd

# Read the file with more lenient parsing
df = pd.read_csv('/kaggle/input/dataset1/dataset (1).csv', 
                 engine='python',  
                 encoding='utf-8',
                 on_bad_lines='skip',    # For newer pandas versions
                 quoting=3)  # Minimal quoting

# Print out details
print(f"Number of rows: {len(df)}")

# Count the total lines in the original file
with open('/kaggle/input/dataset1/dataset (1).csv', 'r', encoding='utf-8') as file:
    total_lines = sum(1 for line in file)

print(f"Total lines in original file: {total_lines}")

# Display sentiment distribution
print("\nSentiment Distribution:")
print(df['Sentiment'].value_counts())
print("\nSentiment Percentage:")
print(df['Sentiment'].value_counts(normalize=True) * 100)

# Optional: Investigate any potential issues
def check_file_integrity(filepath):
    print("\nFile Integrity Check:")
    with open(filepath, 'r', encoding='utf-8') as file:
        for i, line in enumerate(file, 1):
            try:
                # Try to split the line
                parts = line.strip().split(',')
                if len(parts) < 2:
                    print(f"Problematic line {i}: {line.strip()}")
            except Exception as e:
                print(f"Error processing line {i}: {e}")

check_file_integrity('/kaggle/input/dataset1/dataset (1).csv')
# Out:
# Number of rows: 58
# Total lines in original file: 101
#
# Sentiment Distribution:
# Sentiment
# positive    37
# negative    21
# Name: count, dtype: int64
#
# Sentiment Percentage:
# Sentiment
# positive    63.793103
# negative    36.206897
# Name: proportion, dtype: float64
#
# File Integrity Check:
